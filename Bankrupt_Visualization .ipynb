# %%
import seaborn as sns
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
data = pd.read_excel(r'C:/Users/Help/Desktop/bankruptcy_data/data.xlsx')
data.describe()
# Out:
#        Industrial Risk Management Risk Financial Flexibility Credibility  \
# count              250             250                   250         250
# unique               3               3                     3           3
# top                  N               N                     N           N
# freq                89             119                   119          94
#
#        Competitiveness Operating Risk Class
# count              250            250   250
# unique               3              3     2
# top                  N              N    NB
# freq               103            114   143

# %%
le = LabelEncoder()
data_numbers = data[data.columns[:]].apply(le.fit_transform)
data_numbers.head()
# Out:
#    Industrial Risk  Management Risk  Financial Flexibility  Credibility  \
# 0                2                2                      0            0
# 1                1                1                      0            0
# 2                0                0                      0            0
# 3                2                2                      2            2
# 4                1                1                      2            2
#
#    Competitiveness  Operating Risk  Class
# 0                0               2      1
# 1                0               1      1
# 2                0               0      1
# 3                2               2      1
# 4                2               1      1

# %%
sns.pairplot(data_numbers, hue = "Class", vars=["Industrial Risk", "Management Risk", "Financial Flexibility","Credibility","Competitiveness","Operating Risk"])
